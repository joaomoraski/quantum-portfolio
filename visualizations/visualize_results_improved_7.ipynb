# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
max_limit = 6
budget_diff_penalizer = 1


def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)
    

def compare_solutions(data, data2, data3, data4):
    results = {}
    
    for case_id, case_data in data.items():
        n_qubits = case_data["hyperparams"]["n_qubits"]
        cont_sol = data3[case_id]["continuous_variables_solution"]
        exact_sol = data4[case_id]["exact_solution"]
        qaoa_sol = case_data["qaoa_solution"]
        budget = case_data["hyperparams"]["budget"]
        un_cont_sol = data2[case_id]["continuous_variables_solution_unconstrained"]
        
        allocation2 = un_cont_sol["allocation"]
        used_budget = 0
        for stock, weight in allocation2.items():
            used_budget += weight * data2[case_id]["hyperparams"]["prices_now"][stock]
        unconstrained_cont_value = un_cont_sol["value"]
        unconstrained_cont_penalty = budget_diff_penalizer*un_cont_sol["left_overs"]
        
        cont_value = cont_sol["value"]
        cont_penalty = budget_diff_penalizer*cont_sol["left_overs"]

        exact_budgets = exact_sol.get("result_with_budget", [])[0]
        exact_value = exact_budgets.get("objective_value", 0)
        exact_penalty = budget_diff_penalizer*exact_budgets["difference"]

        qaoa_value = qaoa_sol.get("objective_values", [])[-1]
        qaoa_budgets = qaoa_sol.get("result_with_budget", [])[-1]
        qaoa_penalty = budget_diff_penalizer*qaoa_budgets["difference"]

        results[case_id] = {
            "continuous": {"value": cont_value, "penalty": cont_penalty},
            "continuous_unconstrained": {"value": unconstrained_cont_value, "penalty": unconstrained_cont_penalty},
            "exact": {"value": exact_value, "penalty": exact_penalty},
            "qaoa": {"value": qaoa_value, "penalty": qaoa_penalty},
            "n_qubits": n_qubits,
            "budget": budget
        }
    
    return results


def plot_objective_vs_budget(results, save_path=None, dpi=300, fig_height=7):
    """
    Creates a publication-quality scatter plot comparing objective values vs budget utilization,
    with a magnified inset showing the upper right corner.
    
    Parameters:
    -----------
    results : dict
        Dictionary containing the results for each case and method.
    save_path : str, optional
        Path to save the figure. If None, the figure is displayed but not saved.
    dpi : int, optional
        Resolution of the saved figure in dots per inch.
    fig_width : float, optional
        Width of the figure in inches.
    fig_height : float, optional
        Height of the figure in inches.
    
    Returns:
    --------
    fig, ax : tuple
        Figure and axes objects for further customization if needed.
    """
    fig_width = 1.618 * fig_height  # Golden ratio for figure width
    # Set publication-quality parameters
    plt.rcParams.update({
        'font.family': 'sans-serif',
        'font.sans-serif': ['Arial', 'Helvetica', 'DejaVu Sans'],
        'font.size': 16,
        'axes.linewidth': 0.8,
        'axes.labelsize': 16,
        'xtick.labelsize': 14,
        'ytick.labelsize': 14,
        'legend.fontsize': 14,
        'legend.frameon': False,
        'legend.handlelength': 1.5,
        'legend.handletextpad': 0.5
    })
    
    # Create figure and axes
    fig, ax = plt.subplots(figsize=(fig_width, fig_height))
    
    # Set smoke gray background for plotting area
    ax.set_facecolor('#f0f0f0')  # Light smoke gray
    
    # Define a professional color palette (colorblind-friendly)
    colors = ['#0173B2', '#DE8F05', '#029E73']
    markers = ['o', 's', '^', 'P', 'D']
    
    # Extract data for plotting
    continuous_obj_values = []
    exact_obj_values = []
    qaoa_obj_values = []
    unconstrained_obj_values = []
    
    continuous_budget_pct = []
    exact_budget_pct = []
    qaoa_budget_pct = []
    unconstrained_budget_pct = []
    
    case_labels = []
    
    # Process data for plotting
    for case_id, case_data in results.items():
        case_labels.append(case_id)

        vals = [case_data["continuous"]["value"], case_data["exact"]["value"], case_data["qaoa"]["value"], case_data["continuous_unconstrained"]["value"]]
        max_val = max(vals)
        min_val = min(vals)
        obj_range = max_val - min_val
        # Normalize objective values to [0,1] scale
        cont_obj = (case_data["continuous"]["value"] - min_val)/obj_range
        exact_obj = (case_data["exact"]["value"]- min_val)/obj_range
        qaoa_obj = (case_data["qaoa"]["value"]- min_val)/obj_range
        unconstrained_cont_obj = (case_data["continuous_unconstrained"]["value"]- min_val)/obj_range
        
        if case_id == "47":
            print(f"Case {case_id} - cont_obj: {case_data['continuous']['value']}, exact_obj: {case_data['exact']['value']}, qaoa_obj: {case_data['qaoa']['value']}, unconstrained_cont_obj: {case_data['continuous_unconstrained']['value']}")

        continuous_obj_values.append(cont_obj)
        exact_obj_values.append(exact_obj)
        qaoa_obj_values.append(qaoa_obj)
        unconstrained_obj_values.append(unconstrained_cont_obj)
        
        # Calculate budget utilization percentage
        budget = case_data["budget"]
        cont_budget_pct = 100 - case_data["continuous"]["penalty"] / budget * 100
        ex_budget_pct = 100 - case_data["exact"]["penalty"] / budget * 100
        q_budget_pct = 100 - case_data["qaoa"]["penalty"] / budget * 100
        u_budget_pct = 100 - case_data["continuous_unconstrained"]["penalty"] / budget * 100
        
        continuous_budget_pct.append(cont_budget_pct)
        exact_budget_pct.append(ex_budget_pct)
        qaoa_budget_pct.append(q_budget_pct)
        unconstrained_budget_pct.append(u_budget_pct)
    
    # Plot scatter points
    cont_scatter = ax.scatter(continuous_obj_values, continuous_budget_pct, 
                             label="Continuous constrained + discretization", 
                             color=colors[0], marker=markers[0], s=80, 
                             edgecolor='black', linewidth=0.5, alpha=0.8)
    
    unconstrained_scatter = ax.scatter(unconstrained_obj_values, unconstrained_budget_pct, 
                                       label="Continuous unconstrained + discretization", 
                                       color='gray', marker=markers[3], s=80, 
                                       edgecolor='black', linewidth=0.5, alpha=0.8)
    
    exact_scatter = ax.scatter(exact_obj_values, exact_budget_pct, 
                              label="Eigensolver solution to HUBO", 
                              color=colors[1], marker=markers[1], s=80, 
                              edgecolor='black', linewidth=0.5, alpha=0.8)
    
    qaoa_scatter = ax.scatter(qaoa_obj_values, qaoa_budget_pct, 
                             label="QAOA solution to HUBO", 
                             color=colors[2], marker=markers[2], s=80, 
                             edgecolor='black', linewidth=0.5, alpha=0.8)
    
    # Add optimal region highlighting - high objective value and good budget utilization
    #ax.axhspan(95, 105, alpha=0.1, color='green', zorder=0)
    #ax.axvspan(0.95, 1.0, alpha=0.1, color='green', zorder=0)
    
    # Add text labels for cases
    for i, case in enumerate(case_labels):
        font_size = 9
        ax.annotate(case, (continuous_obj_values[i], continuous_budget_pct[i]),
                   xytext=(5, 5), textcoords='offset points', fontsize=font_size)
        ax.annotate(case, (exact_obj_values[i], exact_budget_pct[i]),
                   xytext=(5, 5), textcoords='offset points', fontsize=font_size)
        ax.annotate(case, (qaoa_obj_values[i], qaoa_budget_pct[i]),
                   xytext=(5, 5), textcoords='offset points', fontsize=font_size)
        ax.annotate(case, (unconstrained_obj_values[i], unconstrained_budget_pct[i]),
                    xytext=(5, 5), textcoords='offset points', fontsize=font_size)
    
    # Add reference lines
    ax.axhline(y=100, color='black', linestyle='--', alpha=0.3, zorder=0)
    ax.axvline(x=1, color='black', linestyle='--', alpha=0.3, zorder=0)
    
    # Customize axes
    ax.set_xlabel("Normalized objective value without budget constraint (higher is better)", fontweight='bold')
    ax.set_ylabel("Budget Utilization (%)", fontweight='bold')
    
    # Set axis limits with some padding
    min_obj = min(min(continuous_obj_values), min(exact_obj_values), min(qaoa_obj_values), min(unconstrained_obj_values))
    max_obj = max(max(continuous_obj_values), max(exact_obj_values), max(qaoa_obj_values), max(unconstrained_obj_values))
    obj_margin = (max_obj - min_obj) * 0.1
    ax.set_xlim(min_obj - obj_margin, max_obj + obj_margin)

    min_budget = min(min(continuous_budget_pct), min(exact_budget_pct), min(qaoa_budget_pct), min(unconstrained_budget_pct))
    max_budget = max(max(continuous_budget_pct), max(exact_budget_pct), max(qaoa_budget_pct), max(unconstrained_budget_pct))
    budget_margin = (max_budget - min_budget) * 0.1
    ax.set_ylim(min_budget - budget_margin, max_budget + budget_margin)
    
    # Add grid lines
    ax.grid(True, linestyle='--', alpha=0.7, zorder=0)
    
    # Customize spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Add legend in optimal position
    #ax.legend(loc='lower right', ncol=1)
    
    if True:
    # Create an inset for the magnified view of the upper right corner
    # Determine zoom region boundaries (focus on the upper right corner)
        zoom_x_min = 0.97  # Adjust as needed based on your data
        zoom_x_max = 1.02
        zoom_y_min = 97.5    # Adjust as needed based on your data
        zoom_y_max = 99
        
        # Create the zoomed inset axes (position relative to main axes)
        axins = zoomed_inset_axes(ax, 6, 
                          bbox_to_anchor=(0.5, 0.6), 
                          bbox_transform=ax.transAxes) # zoom factor: 4, location: lower right
        
        # Plot the same data in the inset
        axins.scatter(continuous_obj_values, continuous_budget_pct, 
                    color=colors[0], marker=markers[0], s=60, 
                    edgecolor='black', linewidth=0.5, alpha=0.8)
        
        axins.scatter(exact_obj_values, exact_budget_pct, 
                    color=colors[1], marker=markers[1], s=60, 
                    edgecolor='black', linewidth=0.5, alpha=0.8)
        
        axins.scatter(qaoa_obj_values, qaoa_budget_pct, 
                    color=colors[2], marker=markers[2], s=60, 
                    edgecolor='black', linewidth=0.5, alpha=0.8)
        
        axins.scatter(unconstrained_obj_values, unconstrained_budget_pct, 
                    color='gray', marker=markers[3], s=60, 
                    edgecolor='black', linewidth=0.5, alpha=0.8)
        
        # Add text labels in the inset too, but only for points in the zoom region
        for i, case in enumerate(case_labels):
            # Only add labels for points actually in the zoomed region
            font_size = 8
            if (zoom_x_min <= continuous_obj_values[i] <= zoom_x_max and 
                zoom_y_min <= continuous_budget_pct[i] <= zoom_y_max):
                axins.annotate(case, (continuous_obj_values[i], continuous_budget_pct[i]),
                            xytext=(3, 3), textcoords='offset points', fontsize=font_size)
            
            if (zoom_x_min <= exact_obj_values[i] <= zoom_x_max and 
                zoom_y_min <= exact_budget_pct[i] <= zoom_y_max):
                axins.annotate(case, (exact_obj_values[i], exact_budget_pct[i]),
                            xytext=(3, 3), textcoords='offset points', fontsize=font_size)
            
            if (zoom_x_min <= qaoa_obj_values[i] <= zoom_x_max and 
                zoom_y_min <= qaoa_budget_pct[i] <= zoom_y_max):
                axins.annotate(case, (qaoa_obj_values[i], qaoa_budget_pct[i]),
                            xytext=(3, 3), textcoords='offset points', fontsize=font_size)
            
            if (zoom_x_min <= unconstrained_obj_values[i] <= zoom_x_max and 
                zoom_y_min <= unconstrained_budget_pct[i] <= zoom_y_max):
                axins.annotate(case, (unconstrained_obj_values[i], unconstrained_budget_pct[i]),
                            xytext=(3, 3), textcoords='offset points', fontsize=font_size)
    
        # Set the limits for the inset axes
        axins.set_xlim(zoom_x_min, zoom_x_max)
        axins.set_ylim(zoom_y_min, zoom_y_max)
        
        # Add grid to inset
        axins.grid(True, linestyle='--', alpha=0.7, zorder=0)
        
        # Remove ticks and ticklabels from inset to make it cleaner
        axins.tick_params(axis='both', which='both', labelsize=8)
        
        # Draw connecting lines between the main axes and the inset
        mark_inset(ax, axins, loc1=2, loc2=1, fc="none", ec="0.5")
    
    # Adjust layout
    #plt.tight_layout()
    
    # Save if path is provided
    if save_path:
        plt.savefig(save_path, dpi=dpi, bbox_inches='tight')
    
    return fig, ax

# %%
def main():
        # Define the lambda folders to check
    lambda_folders = {
        0.001: "lambda_0001",
        0.01: "lambda_001",
        0.1: "lambda_01",
        1.0: "lambda_1",
        0.9: "lambda_09",
        10.0: "lambda_10",
        100.0: "lambda_100",
        1000.0: "lambda_1000"
    }
    
    method = "cmaes"
    base_path = f"../results/{method}_hubo_results/"
    
    # Dictionary to store the best results and lambdas for each case
    data = {}
    best_lambdas = {}

    best_exact_data = {}
    best_exact_lambdas = {}
    
    # Process each lambda folder
    for lambda_val, lambda_folder in lambda_folders.items():
        folder_path = os.path.join(base_path, lambda_folder)
        if not os.path.exists(folder_path):
            print(f"Warning: Folder {folder_path} does not exist. Skipping.")
            continue
            
        # Load all files in this lambda folder
        print(f"Processing lambda={lambda_val} folder...")
        files = [file for file in os.listdir(folder_path) if "portfolio_optimization_" in file]
        
        # Process each file
        for file in files:
            file_path = os.path.join(folder_path, file)
            file_data = load_json(file_path)
            
            # For each case in the file
            for case_id, case_data in file_data.items():
                # Skip if no QAOA solution
                if 'qaoa_solution' not in case_data or 'final_expectation_value' not in case_data['qaoa_solution']:
                    continue
                    
                # Get expectation value
                expectation_val = case_data['qaoa_solution']['objective_values'][-1]
                
                # If we haven't seen this case before, or if this result is better
                if case_id not in data or expectation_val > data[case_id]['qaoa_solution']['objective_values'][-1]:
                    data[case_id] = case_data
                    best_lambdas[case_id] = lambda_val

                if 'exact_solution' in case_data:
                    exact_expectation_val = case_data['exact_solution']['smallest_eigenvalues'][0]
                    if case_id not in best_exact_data:
                        best_exact_data[case_id] = case_data
                        best_exact_lambdas[case_id] = lambda_val
                        print(f"New exact solution for case {case_id} with lambda {lambda_val}: {exact_expectation_val}")
                    elif exact_expectation_val < best_exact_data[case_id]['exact_solution']['smallest_eigenvalues'][0]:
                        
                        print(f"Updated exact solution for case {case_id} with lambda {lambda_val}: {exact_expectation_val}")
                        print("Difference in expectation value:", 
                              best_exact_data[case_id]['exact_solution']['smallest_eigenvalues'][0] - exact_expectation_val)
                        best_exact_data[case_id] = case_data
                        best_exact_lambdas[case_id] = lambda_val
    
    data2 = load_json("../results/classical_unconstrained/filtered_portfolio_optimization_results.json")
    data3 = load_json("../results/classical_constrained/filtered_portfolio_optimization_results.json")
    data4 = load_json("../results/exact_eigensolver/filtered_portfolio_optimization_results.json")
    
    print(f"Loaded {len(data)} cases.")
    nqubits = 7
    path = f"./{nqubits}_qubits"
    results = compare_solutions(data, data2, data3, data4)
    
    subset_of_results = {}
    for key in list(results.keys()):
        n_qubits = results[key]["n_qubits"]
        if n_qubits == nqubits:
            subset_of_results[key] = results[key]
    
    # Use the new plotting function
    fig, ax = plot_objective_vs_budget(subset_of_results, save_path=path + "_obj_vs_budget.png")
    
    # Also keep the original plot for comparison
    #plot_scores(subset_of_results, save_path=path)
    return data

data = main()
# Out:
# Processing lambda=0.001 folder...
# New exact solution for case 34 with lambda 0.001: -0.3016255322259839
# New exact solution for case 10 with lambda 0.001: -0.1494451333659771
# New exact solution for case 31 with lambda 0.001: -0.36533099125522966
# New exact solution for case 87 with lambda 0.001: -0.31097876130718133
# New exact solution for case 80 with lambda 0.001: -0.1930630329613203
# New exact solution for case 38 with lambda 0.001: -0.18848487232404118
# New exact solution for case 64 with lambda 0.001: -0.0006565636619055471
# New exact solution for case 23 with lambda 0.001: -0.29322969452899805
# New exact solution for case 51 with lambda 0.001: -0.0023180021641140457
# New exact solution for case 41 with lambda 0.001: -0.030190188497222215
# New exact solution for case 20 with lambda 0.001: -0.28922349712232576
# New exact solution for case 82 with lambda 0.001: -0.2735580690796039
# New exact solution for case 17 with lambda 0.001: -0.010661515162326492
# New exact solution for case 42 with lambda 0.001: -0.03719896646841599
# New exact solution for case 15 with lambda 0.001: -0.0004300220168638785
# New exact solution for case 53 with lambda 0.001: -0.06445552998656627
# New exact solution for case 9 with lambda 0.001: -0.0800097304053089
# New exact solution for case 8 with lambda 0.001: -0.0973782226066001
# New exact solution for case 94 with lambda 0.001: -0.2355103645556099
# New exact solution for case 54 with lambda 0.001: -0.06559080872657282
# New exact solution for case 37 with lambda 0.001: -0.0012289471895459835
# New exact solution for case 19 with lambda 0.001: -0.022300160187078106
# New exact solution for case 86 with lambda 0.001: -0.11844261968298002
# New exact solution for case 13 with lambda 0.001: -0.0012632480268160184
# New exact solution for case 81 with lambda 0.001: -0.2648589453366046
# New exact solution for case 62 with lambda 0.001: -0.017932000059634745
# New exact solution for case 39 with lambda 0.001: -0.06655476509226488
# New exact solution for case 65 with lambda 0.001: -0.036219710012274295
# New exact solution for case 84 with lambda 0.001: -0.6116761835714929
# New exact solution for case 26 with lambda 0.001: -0.21339725198044915
# New exact solution for case 6 with lambda 0.001: -0.024068761216578714
# New exact solution for case 75 with lambda 0.001: -0.006136284586511707
# New exact solution for case 74 with lambda 0.001: -0.015992077923202855
# New exact solution for case 70 with lambda 0.001: -0.0062667849771167366
# New exact solution for case 66 with lambda 0.001: -0.001383871159476471
# New exact solution for case 79 with lambda 0.001: -0.1348550828167154
# New exact solution for case 52 with lambda 0.001: -0.0686906610768912
# New exact solution for case 45 with lambda 0.001: -0.0174998938140001
# New exact solution for case 27 with lambda 0.001: -0.4263419834245756
# New exact solution for case 14 with lambda 0.001: -0.019285193987787625
# New exact solution for case 21 with lambda 0.001: -0.2803804559228066
# New exact solution for case 67 with lambda 0.001: -0.04412629500973017
# New exact solution for case 43 with lambda 0.001: -0.02257419895582514
# New exact solution for case 5 with lambda 0.001: -0.16789252665246157
# New exact solution for case 99 with lambda 0.001: -0.30357789130941243
# New exact solution for case 16 with lambda 0.001: -0.03911042124669086
# New exact solution for case 1 with lambda 0.001: -0.06352061745441348
# New exact solution for case 7 with lambda 0.001: -0.34771639650250025
# New exact solution for case 25 with lambda 0.001: -0.5635425971244704
# New exact solution for case 18 with lambda 0.001: -0.004384626736194931
# New exact solution for case 98 with lambda 0.001: -0.5189909309658393
# New exact solution for case 3 with lambda 0.001: -0.05160741699296673
# New exact solution for case 85 with lambda 0.001: -0.3186083860667906
# New exact solution for case 2 with lambda 0.001: -0.24101342287756278
# New exact solution for case 40 with lambda 0.001: -0.03109713292574516
# New exact solution for case 12 with lambda 0.001: 0.0006313557066789118
# New exact solution for case 49 with lambda 0.001: -0.035278219071327666
# New exact solution for case 69 with lambda 0.001: -0.0016437243947263747
# New exact solution for case 44 with lambda 0.001: 0.0004888653251300489
# New exact solution for case 68 with lambda 0.001: -0.04051294920753219
# New exact solution for case 22 with lambda 0.001: -0.5375938769992901
# New exact solution for case 83 with lambda 0.001: -0.25138191457618125
# New exact solution for case 63 with lambda 0.001: -0.08584201777461506
# New exact solution for case 11 with lambda 0.001: -0.01022012803225744
# New exact solution for case 36 with lambda 0.001: -0.009503302671152541
# New exact solution for case 78 with lambda 0.001: -0.05244814010411727
# New exact solution for case 4 with lambda 0.001: -0.06905016876548033
# New exact solution for case 24 with lambda 0.001: -0.11813552641626988
# New exact solution for case 0 with lambda 0.001: -0.17546267589347572
# New exact solution for case 77 with lambda 0.001: -0.09480089046865692
# Processing lambda=0.01 folder...
# Updated exact solution for case 70 with lambda 0.01: -0.060359527727070504
# Difference in expectation value: 0.054092742749953765
# Updated exact solution for case 68 with lambda 0.01: -0.21258536352556445
# Difference in expectation value: 0.17207241431803227
# Updated exact solution for case 4 with lambda 0.01: -0.2204700745828519
# Difference in expectation value: 0.15141990581737158
# Updated exact solution for case 0 with lambda 0.01: -0.24422192820834093
# Difference in expectation value: 0.06875925231486521
# Updated exact solution for case 75 with lambda 0.01: -0.056983553173772114
# Difference in expectation value: 0.05084726858726041
# Updated exact solution for case 31 with lambda 0.01: -0.43412775883742843
# Difference in expectation value: 0.06879676758219877
# New exact solution for case 96 with lambda 0.01: -0.6225202714029396
# New exact solution for case 33 with lambda 0.01: -0.2471428129227598
# Updated exact solution for case 83 with lambda 0.01: -0.2760060422489417
# Difference in expectation value: 0.024624127672760454
# New exact solution for case 73 with lambda 0.01: -0.12310493205091971
# Updated exact solution for case 38 with lambda 0.01: -0.19174267083843502
# Difference in expectation value: 0.0032577985143938393
# Updated exact solution for case 22 with lambda 0.01: -0.5463912147939793
# Difference in expectation value: 0.008797337794689275
# Updated exact solution for case 85 with lambda 0.01: -0.3221959904097235
# Difference in expectation value: 0.0035876043429329263
# Updated exact solution for case 14 with lambda 0.01: -0.07806578958669504
# Difference in expectation value: 0.058780595598907415
# Updated exact solution for case 39 with lambda 0.01: -0.06717140070347961
# Difference in expectation value: 0.0006166356112147359
# New exact solution for case 57 with lambda 0.01: -0.133582559363365
# Updated exact solution for case 87 with lambda 0.01: -0.5471222265207657
# Difference in expectation value: 0.23614346521358437
# Updated exact solution for case 98 with lambda 0.01: -0.5262364691210641
# Difference in expectation value: 0.007245538155224884
# New exact solution for case 90 with lambda 0.01: -0.20186366223974167
# Updated exact solution for case 40 with lambda 0.01: -0.040951458450039266
# Difference in expectation value: 0.009854325524294105
# New exact solution for case 59 with lambda 0.01: -0.06250101164878961
# Updated exact solution for case 77 with lambda 0.01: -0.16614079090536507
# Difference in expectation value: 0.07133990043670815
# New exact solution for case 76 with lambda 0.01: -0.0012482694374335945
# Updated exact solution for case 10 with lambda 0.01: -0.21388650083989122
# Difference in expectation value: 0.06444136747391413
# Updated exact solution for case 64 with lambda 0.01: -0.00637564568599292
# Difference in expectation value: 0.005719082024087373
# Updated exact solution for case 69 with lambda 0.01: -0.015443653303554527
# Difference in expectation value: 0.013799928908828153
# New exact solution for case 71 with lambda 0.01: -0.027533197718254104
# Updated exact solution for case 65 with lambda 0.01: -0.037389051253186874
# Difference in expectation value: 0.001169341240912579
# Updated exact solution for case 52 with lambda 0.01: -0.15748253379075952
# Difference in expectation value: 0.08879187271386832
# Updated exact solution for case 21 with lambda 0.01: -0.3166868051904908
# Difference in expectation value: 0.036306349267684224
# Updated exact solution for case 74 with lambda 0.01: -0.10956220481635758
# Difference in expectation value: 0.09357012689315472
# Updated exact solution for case 53 with lambda 0.01: -0.10643828674012985
# Difference in expectation value: 0.04198275675356358
# New exact solution for case 95 with lambda 0.01: -0.3536255427579553
# Updated exact solution for case 11 with lambda 0.01: -0.08871847297880985
# Difference in expectation value: 0.0784983449465524
# Updated exact solution for case 80 with lambda 0.01: -0.20361698438551423
# Difference in expectation value: 0.010553951424193936
# Updated exact solution for case 1 with lambda 0.01: -0.2470113408186999
# Difference in expectation value: 0.18349072336428643
# New exact solution for case 72 with lambda 0.01: -0.13139727506945828
# New exact solution for case 92 with lambda 0.01: -0.13910603408914324
# Updated exact solution for case 67 with lambda 0.01: -0.11582000670419666
# Difference in expectation value: 0.07169371169446649
# New exact solution for case 60 with lambda 0.01: -0.11469125589990166
# New exact solution for case 93 with lambda 0.01: -0.22520602741238785
# Updated exact solution for case 2 with lambda 0.01: -0.2561000617746168
# Difference in expectation value: 0.015086638897054028
# Updated exact solution for case 34 with lambda 0.01: -0.3949764229135683
# Difference in expectation value: 0.09335089068758445
# Updated exact solution for case 81 with lambda 0.01: -0.2655742992277751
# Difference in expectation value: 0.0007153538911705004
# Updated exact solution for case 20 with lambda 0.01: -0.3131769151493676
# Difference in expectation value: 0.023953418027041817
# New exact solution for case 32 with lambda 0.01: -0.24876373570888394
# Updated exact solution for case 9 with lambda 0.01: -0.2804758274119806
# Difference in expectation value: 0.20046609700667173
# Updated exact solution for case 5 with lambda 0.01: -0.24279091120506177
# Difference in expectation value: 0.0748983845526002
# Updated exact solution for case 43 with lambda 0.01: -0.09058044711471328
# Difference in expectation value: 0.06800624815888813
# Updated exact solution for case 3 with lambda 0.01: -0.0661598620221533
# Difference in expectation value: 0.014552445029186574
# New exact solution for case 28 with lambda 0.01: -0.5096652740714337
# Updated exact solution for case 25 with lambda 0.01: -0.6121989433619821
# Difference in expectation value: 0.048656346237511694
# Updated exact solution for case 37 with lambda 0.01: -0.011610575151283458
# Difference in expectation value: 0.010381627961737474
# New exact solution for case 56 with lambda 0.01: -0.011680548135065628
# Updated exact solution for case 86 with lambda 0.01: -0.12319206799758146
# Difference in expectation value: 0.0047494483146014455
# Updated exact solution for case 51 with lambda 0.01: -0.03040450616720571
# Difference in expectation value: 0.028086504003091664
# Updated exact solution for case 45 with lambda 0.01: -0.08282189270197166
# Difference in expectation value: 0.06532199888797155
# New exact solution for case 46 with lambda 0.01: -0.046293564358932913
# New exact solution for case 61 with lambda 0.01: -0.11475698296804605
# Updated exact solution for case 63 with lambda 0.01: -0.09610143056896608
# Difference in expectation value: 0.010259412794351025
# Updated exact solution for case 12 with lambda 0.01: -0.0029530210472153455
# Difference in expectation value: 0.003584376753894257
# New exact solution for case 89 with lambda 0.01: -0.14314040551340346
# Updated exact solution for case 13 with lambda 0.01: -0.01157411268538393
# Difference in expectation value: 0.010310864658567911
# Updated exact solution for case 94 with lambda 0.01: -0.2370410922285113
# Difference in expectation value: 0.0015307276729014108
# New exact solution for case 47 with lambda 0.01: -0.02913877417236774
# Updated exact solution for case 17 with lambda 0.01: -0.05666443792001641
# Difference in expectation value: 0.04600292275768991
# Updated exact solution for case 41 with lambda 0.01: -0.03515791060864175
# Difference in expectation value: 0.004967722111419534
# Updated exact solution for case 36 with lambda 0.01: -0.08159248913230194
# Difference in expectation value: 0.0720891864611494
# Updated exact solution for case 24 with lambda 0.01: -0.1212461829424416
# Difference in expectation value: 0.0031106565261717206
# New exact solution for case 88 with lambda 0.01: -0.38820691365900456
# Updated exact solution for case 23 with lambda 0.01: -0.3029354791747485
# Difference in expectation value: 0.009705784645750448
# Updated exact solution for case 66 with lambda 0.01: -0.01519124862082989
# Difference in expectation value: 0.01380737746135342
# Updated exact solution for case 99 with lambda 0.01: -0.30386924723632713
# Difference in expectation value: 0.0002913559269147048
# Updated exact solution for case 27 with lambda 0.01: -0.42879267553126427
# Difference in expectation value: 0.00245069210668869
# Updated exact solution for case 8 with lambda 0.01: -0.3009265868267219
# Difference in expectation value: 0.2035483642201218
# Updated exact solution for case 54 with lambda 0.01: -0.09806512557290167
# Difference in expectation value: 0.03247431684632886
# New exact solution for case 50 with lambda 0.01: -0.1747069322360037
# New exact solution for case 30 with lambda 0.01: -0.11442525010743082
# Updated exact solution for case 7 with lambda 0.01: -0.5527882774125327
# Difference in expectation value: 0.20507188091003242
# New exact solution for case 35 with lambda 0.01: -0.3826999573248065
# Updated exact solution for case 62 with lambda 0.01: -0.12761433835332278
# Difference in expectation value: 0.10968233829368804
# New exact solution for case 91 with lambda 0.01: -0.35076858663056093
# Updated exact solution for case 79 with lambda 0.01: -0.20167868740179648
# Difference in expectation value: 0.06682360458508108
# Updated exact solution for case 19 with lambda 0.01: -0.05801123444859417
# Difference in expectation value: 0.03571107426151607
# Updated exact solution for case 44 with lambda 0.01: -0.0003703914031204931
# Difference in expectation value: 0.000859256728250542
# New exact solution for case 58 with lambda 0.01: -0.12440008766207664
# Updated exact solution for case 49 with lambda 0.01: -0.10293941789287075
# Difference in expectation value: 0.06766119882154309
# Updated exact solution for case 15 with lambda 0.01: -0.004086677280253559
# Difference in expectation value: 0.00365665526338968
# Updated exact solution for case 16 with lambda 0.01: -0.04157348485192959
# Difference in expectation value: 0.0024630636052387286
# Updated exact solution for case 18 with lambda 0.01: -0.03547124202493943
# Difference in expectation value: 0.031086615288744502
# Updated exact solution for case 6 with lambda 0.01: -0.1608157938883511
# Difference in expectation value: 0.13674703267177238
# Updated exact solution for case 26 with lambda 0.01: -0.21805167381936802
# Difference in expectation value: 0.004654421838918871
# Updated exact solution for case 78 with lambda 0.01: -0.052632884782751625
# Difference in expectation value: 0.00018474467863435762
# New exact solution for case 55 with lambda 0.01: -0.20880111580059843
# New exact solution for case 29 with lambda 0.01: -0.041751588693676685
# New exact solution for case 48 with lambda 0.01: -0.04751795313367739
# Updated exact solution for case 42 with lambda 0.01: -0.05252033960266584
# Difference in expectation value: 0.015321373134249847
# New exact solution for case 97 with lambda 0.01: -0.6341312326204892
# Updated exact solution for case 82 with lambda 0.01: -0.2864108380733308
# Difference in expectation value: 0.012852768993726893
# Processing lambda=0.1 folder...
# Updated exact solution for case 50 with lambda 0.1: -0.20095143072304283
# Difference in expectation value: 0.026244498487039136
# Updated exact solution for case 73 with lambda 0.1: -0.12397375728133518
# Difference in expectation value: 0.0008688252304154681
# Updated exact solution for case 85 with lambda 0.1: -0.322571190893201
# Difference in expectation value: 0.00037520048347750024
# Updated exact solution for case 99 with lambda 0.1: -0.30390092211154296
# Difference in expectation value: 3.167487521582579e-05
# Updated exact solution for case 60 with lambda 0.1: -0.11613234429110987
# Difference in expectation value: 0.0014410883912082117
# Updated exact solution for case 0 with lambda 0.1: -0.25305570385475284
# Difference in expectation value: 0.008833775646411912
# Updated exact solution for case 93 with lambda 0.1: -0.2253907965516324
# Difference in expectation value: 0.00018476913924456162
# Updated exact solution for case 51 with lambda 0.1: -0.17777002010404008
# Difference in expectation value: 0.14736551393683436
# Updated exact solution for case 3 with lambda 0.1: -0.06808387823617251
# Difference in expectation value: 0.0019240162140192058
# Updated exact solution for case 22 with lambda 0.1: -0.5472909978789519
# Difference in expectation value: 0.0008997830849725164
# Updated exact solution for case 46 with lambda 0.1: -0.0499723098708799
# Difference in expectation value: 0.003678745511946989
# Updated exact solution for case 48 with lambda 0.1: -0.04809747999199143
# Difference in expectation value: 0.0005795268583140417
# Updated exact solution for case 25 with lambda 0.1: -0.6164295922570202
# Difference in expectation value: 0.004230648895038103
# Updated exact solution for case 15 with lambda 0.1: -0.02668607282809613
# Difference in expectation value: 0.02259939554784257
# Updated exact solution for case 95 with lambda 0.1: -0.3538869538573018
# Difference in expectation value: 0.00026141109934646467
# Updated exact solution for case 77 with lambda 0.1: -0.1795225651196558
# Difference in expectation value: 0.013381774214290737
# Updated exact solution for case 29 with lambda 0.1: -0.1752718677843312
# Difference in expectation value: 0.13352027909065453
# Updated exact solution for case 90 with lambda 0.1: -0.20188533280257473
# Difference in expectation value: 2.1670562833059348e-05
# Updated exact solution for case 54 with lambda 0.1: -0.1018002156003463
# Difference in expectation value: 0.0037350900274446264
# Updated exact solution for case 7 with lambda 0.1: -0.5870279917340253
# Difference in expectation value: 0.03423971432149264
# Updated exact solution for case 33 with lambda 0.1: -0.2555674815859917
# Difference in expectation value: 0.008424668663231882
# Updated exact solution for case 30 with lambda 0.1: -0.33320433620129686
# Difference in expectation value: 0.21877908609386604
# Updated exact solution for case 64 with lambda 0.1: -0.04340166318115571
# Difference in expectation value: 0.03702601749516279
# Updated exact solution for case 83 with lambda 0.1: -0.2787252772831612
# Difference in expectation value: 0.0027192350342195026
# Updated exact solution for case 63 with lambda 0.1: -0.09726333734498588
# Difference in expectation value: 0.0011619067760197943
# Updated exact solution for case 10 with lambda 0.1: -0.22116160046433272
# Difference in expectation value: 0.007275099624441506
# Updated exact solution for case 74 with lambda 0.1: -0.23712701827365099
# Difference in expectation value: 0.12756481345729342
# Updated exact solution for case 70 with lambda 0.1: -0.2998403653092056
# Difference in expectation value: 0.2394808375821351
# Updated exact solution for case 11 with lambda 0.1: -0.22427522661623925
# Difference in expectation value: 0.13555675363742942
# Updated exact solution for case 53 with lambda 0.1: -0.11384327098532038
# Difference in expectation value: 0.007404984245190524
# Updated exact solution for case 61 with lambda 0.1: -0.11685632860498425
# Difference in expectation value: 0.002099345636938199
# Updated exact solution for case 17 with lambda 0.1: -0.0993456542084284
# Difference in expectation value: 0.042681216288412
# Updated exact solution for case 9 with lambda 0.1: -0.33586772099406736
# Difference in expectation value: 0.05539189358208674
# Updated exact solution for case 21 with lambda 0.1: -0.3209201523979297
# Difference in expectation value: 0.004233347207438898
# Updated exact solution for case 27 with lambda 0.1: -0.4290391947845501
# Difference in expectation value: 0.00024651925328583735
# Updated exact solution for case 34 with lambda 0.1: -0.4074476753349136
# Difference in expectation value: 0.01247125242134528
# Updated exact solution for case 55 with lambda 0.1: -0.22487464658930162
# Difference in expectation value: 0.01607353078870319
# Updated exact solution for case 26 with lambda 0.1: -0.2183790070278776
# Difference in expectation value: 0.0003273332085095837
# Updated exact solution for case 36 with lambda 0.1: -0.2789998876952239
# Difference in expectation value: 0.19740739856292194
# Updated exact solution for case 71 with lambda 0.1: -0.18131191267762675
# Difference in expectation value: 0.15377871495937265
# Updated exact solution for case 5 with lambda 0.1: -0.25278166440348104
# Difference in expectation value: 0.009990753198419272
# Updated exact solution for case 24 with lambda 0.1: -0.12156666164175095
# Difference in expectation value: 0.0003204786993093456
# Updated exact solution for case 66 with lambda 0.1: -0.11074214828752178
# Difference in expectation value: 0.09555089966669189
# Updated exact solution for case 1 with lambda 0.1: -0.30190606070091863
# Difference in expectation value: 0.05489471988221872
# Updated exact solution for case 79 with lambda 0.1: -0.2091867225220309
# Difference in expectation value: 0.00750803512023443
# Updated exact solution for case 68 with lambda 0.1: -0.2949258741289414
# Difference in expectation value: 0.08234051060337694
# Updated exact solution for case 19 with lambda 0.1: -0.06908698393186358
# Difference in expectation value: 0.011075749483269406
# Updated exact solution for case 4 with lambda 0.1: -0.25355491586895595
# Difference in expectation value: 0.03308484128610406
# Updated exact solution for case 43 with lambda 0.1: -0.12942795248226666
# Difference in expectation value: 0.03884750536755338
# Updated exact solution for case 28 with lambda 0.1: -0.5251816514104053
# Difference in expectation value: 0.015516377338971599
# Updated exact solution for case 88 with lambda 0.1: -0.41308420366308807
# Difference in expectation value: 0.024877290004083508
# Updated exact solution for case 52 with lambda 0.1: -0.18032982061791375
# Difference in expectation value: 0.02284728682715423
# Updated exact solution for case 42 with lambda 0.1: -0.05477874480953272
# Difference in expectation value: 0.002258405206866883
# Updated exact solution for case 76 with lambda 0.1: -0.012394542438657948
# Difference in expectation value: 0.011146273001224354
# Updated exact solution for case 18 with lambda 0.1: -0.12131926775526383
# Difference in expectation value: 0.0858480257303244
# Updated exact solution for case 58 with lambda 0.1: -0.12800124190510392
# Difference in expectation value: 0.003601154243027288
# Updated exact solution for case 69 with lambda 0.1: -0.09598948069405053
# Difference in expectation value: 0.080545827390496
# Updated exact solution for case 67 with lambda 0.1: -0.13823379149281328
# Difference in expectation value: 0.022413784788616622
# Updated exact solution for case 37 with lambda 0.1: -0.07479451697306709
# Difference in expectation value: 0.06318394182178363
# Updated exact solution for case 12 with lambda 0.1: -0.021580251806310985
# Difference in expectation value: 0.01862723075909564
# Updated exact solution for case 91 with lambda 0.1: -0.35115386734722653
# Difference in expectation value: 0.0003852807166656036
# Updated exact solution for case 39 with lambda 0.1: -0.06723573911200874
# Difference in expectation value: 6.433840852912431e-05
# Updated exact solution for case 59 with lambda 0.1: -0.09221180049912106
# Difference in expectation value: 0.029710788850331446
# Updated exact solution for case 40 with lambda 0.1: -0.042300313325111104
# Difference in expectation value: 0.001348854875071838
# Updated exact solution for case 75 with lambda 0.1: -0.19900329357644264
# Difference in expectation value: 0.1420197404026705
# Updated exact solution for case 8 with lambda 0.1: -0.35611580675300947
# Difference in expectation value: 0.05518921992628756
# Updated exact solution for case 6 with lambda 0.1: -0.2852998309108563
# Difference in expectation value: 0.12448403702250521
# Updated exact solution for case 78 with lambda 0.1: -0.05265143717043823
# Difference in expectation value: 1.855238768660311e-05
# Updated exact solution for case 31 with lambda 0.1: -0.44238939763946455
# Difference in expectation value: 0.00826163880203612
# Updated exact solution for case 16 with lambda 0.1: -0.04183858666482372
# Difference in expectation value: 0.0002651018128941307
# Updated exact solution for case 87 with lambda 0.1: -0.5919937439115218
# Difference in expectation value: 0.04487151739075612
# Updated exact solution for case 35 with lambda 0.1: -0.3919193896796261
# Difference in expectation value: 0.00921943235481959
# Updated exact solution for case 86 with lambda 0.1: -0.12368907314460882
# Difference in expectation value: 0.0004970051470273573
# Updated exact solution for case 38 with lambda 0.1: -0.19207471757755445
# Difference in expectation value: 0.00033204673911943483
# Updated exact solution for case 81 with lambda 0.1: -0.26564606276449054
# Difference in expectation value: 7.176353671545233e-05
# Updated exact solution for case 44 with lambda 0.1: -0.011286795356876336
# Difference in expectation value: 0.010916403953755843
# Updated exact solution for case 80 with lambda 0.1: -0.20468074202941391
# Difference in expectation value: 0.001063757643899682
# Updated exact solution for case 89 with lambda 0.1: -0.14336373448208212
# Difference in expectation value: 0.00022332896867865992
# Updated exact solution for case 14 with lambda 0.1: -0.11223835381323656
# Difference in expectation value: 0.034172564226541524
# Updated exact solution for case 94 with lambda 0.1: -0.2371952529067331
# Difference in expectation value: 0.00015416067822179857
# Updated exact solution for case 13 with lambda 0.1: -0.0627267281260294
# Difference in expectation value: 0.05115261544064548
# Updated exact solution for case 49 with lambda 0.1: -0.1273397598572848
# Difference in expectation value: 0.02440034196441404
# Updated exact solution for case 47 with lambda 0.1: -0.029377136352134323
# Difference in expectation value: 0.00023836217976658247
# Updated exact solution for case 2 with lambda 0.1: -0.25770906725945575
# Difference in expectation value: 0.0016090054848389435
# Updated exact solution for case 20 with lambda 0.1: -0.3158104258084949
# Difference in expectation value: 0.002633510659127314
# Updated exact solution for case 96 with lambda 0.1: -0.6225237772806547
# Difference in expectation value: 3.5058777150265286e-06
# Updated exact solution for case 23 with lambda 0.1: -0.303954554347823
# Difference in expectation value: 0.0010190751730744796
# Updated exact solution for case 65 with lambda 0.1: -0.037512607559337774
# Difference in expectation value: 0.00012355630615090013
# Updated exact solution for case 45 with lambda 0.1: -0.13175592936717379
# Difference in expectation value: 0.04893403666520213
# Updated exact solution for case 98 with lambda 0.1: -0.5270108435578721
# Difference in expectation value: 0.0007743744368079453
# Updated exact solution for case 41 with lambda 0.1: -0.035745336394312634
# Difference in expectation value: 0.000587425785670885
# Updated exact solution for case 72 with lambda 0.1: -0.13281536360493187
# Difference in expectation value: 0.001418088535473594
# Updated exact solution for case 82 with lambda 0.1: -0.2877587936713619
# Difference in expectation value: 0.0013479555980311364
# Updated exact solution for case 92 with lambda 0.1: -0.1392387851866117
# Difference in expectation value: 0.00013275109746846425
# Updated exact solution for case 62 with lambda 0.1: -0.2634104413559954
# Difference in expectation value: 0.1357961030026726
# Processing lambda=1.0 folder...
# Updated exact solution for case 37 with lambda 1.0: -0.3385763118652038
# Difference in expectation value: 0.2637817948921367
# Updated exact solution for case 45 with lambda 1.0: -0.13763521257629233
# Difference in expectation value: 0.005879283209118541
# Updated exact solution for case 52 with lambda 1.0: -0.18131151920632077
# Difference in expectation value: 0.0009816985884070206
# Updated exact solution for case 35 with lambda 1.0: -0.3928652756970505
# Difference in expectation value: 0.0009458860174244021
# Updated exact solution for case 14 with lambda 1.0: -0.11737610656992845
# Difference in expectation value: 0.005137752756691885
# Updated exact solution for case 55 with lambda 1.0: -0.22537338432131893
# Difference in expectation value: 0.000498737732017307
# Updated exact solution for case 54 with lambda 1.0: -0.10297281555936376
# Difference in expectation value: 0.001172599959017459
# Updated exact solution for case 96 with lambda 1.0: -0.6232096138461831
# Difference in expectation value: 0.0006858365655284526
# Updated exact solution for case 43 with lambda 1.0: -0.1325895740622248
# Difference in expectation value: 0.0031616215799581404
# Updated exact solution for case 56 with lambda 1.0: -0.09343748566839924
# Difference in expectation value: 0.08175693753333362
# Updated exact solution for case 68 with lambda 1.0: -0.3042721351688571
# Difference in expectation value: 0.009346261039915704
# Updated exact solution for case 77 with lambda 1.0: -0.18097868066588008
# Difference in expectation value: 0.001456115546224268
# Updated exact solution for case 59 with lambda 1.0: -0.09681169002623301
# Difference in expectation value: 0.004599889527111947
# Updated exact solution for case 8 with lambda 1.0: -0.36275911355779356
# Difference in expectation value: 0.006643306804784088
# Updated exact solution for case 93 with lambda 1.0: -0.22541728370535738
# Difference in expectation value: 2.6487153724968904e-05
# Updated exact solution for case 33 with lambda 1.0: -0.2564405279822397
# Difference in expectation value: 0.0008730463962480228
# Updated exact solution for case 76 with lambda 1.0: -0.10857883580883063
# Difference in expectation value: 0.09618429337017267
# Updated exact solution for case 9 with lambda 1.0: -0.34264393329632054
# Difference in expectation value: 0.006776212302253171
# Updated exact solution for case 44 with lambda 1.0: -0.062229002361986155
# Difference in expectation value: 0.05094220700510982
# Updated exact solution for case 72 with lambda 1.0: -0.13295892171565787
# Difference in expectation value: 0.00014355811072599978
# Updated exact solution for case 19 with lambda 1.0: -0.0704337095342827
# Difference in expectation value: 0.0013467256024191215
# Updated exact solution for case 13 with lambda 1.0: -0.11238562876200932
# Difference in expectation value: 0.04965890063597991
# Updated exact solution for case 16 with lambda 1.0: -0.04186528206337376
# Difference in expectation value: 2.6695398550040383e-05
# Updated exact solution for case 5 with lambda 1.0: -0.25291957934984494
# Difference in expectation value: 0.0001379149463638929
# Updated exact solution for case 23 with lambda 1.0: -0.30405707084808953
# Difference in expectation value: 0.00010251650026654735
# Updated exact solution for case 71 with lambda 1.0: -0.3037499609269571
# Difference in expectation value: 0.12243804824933036
# Updated exact solution for case 82 with lambda 1.0: -0.28789424675687536
# Difference in expectation value: 0.00013545308551343727
# Updated exact solution for case 12 with lambda 1.0: -0.08877253852152683
# Difference in expectation value: 0.06719228671521585
# Updated exact solution for case 69 with lambda 1.0: -0.1965694730503816
# Difference in expectation value: 0.10057999235633108
# Updated exact solution for case 17 with lambda 1.0: -0.10743901273061021
# Difference in expectation value: 0.008093358522181807
# Updated exact solution for case 60 with lambda 1.0: -0.11627849729164529
# Difference in expectation value: 0.00014615300053541502
# Updated exact solution for case 25 with lambda 1.0: -0.6164298643876711
# Difference in expectation value: 2.721306509023691e-07
# Updated exact solution for case 29 with lambda 1.0: -0.24700276322343354
# Difference in expectation value: 0.07173089543910233
# Updated exact solution for case 88 with lambda 1.0: -0.4157911729313545
# Difference in expectation value: 0.0027069692682664126
# Updated exact solution for case 6 with lambda 1.0: -0.3052683148859604
# Difference in expectation value: 0.01996848397510409
# Updated exact solution for case 64 with lambda 1.0: -0.10312498859558891
# Difference in expectation value: 0.059723325414433204
# Updated exact solution for case 11 with lambda 1.0: -0.24941570935894566
# Difference in expectation value: 0.025140482742706416
# Updated exact solution for case 20 with lambda 1.0: -0.3160807442358563
# Difference in expectation value: 0.00027031842736141565
# Updated exact solution for case 18 with lambda 1.0: -0.16004133215943214
# Difference in expectation value: 0.03872206440416831
# Updated exact solution for case 73 with lambda 1.0: -0.12406137275027876
# Difference in expectation value: 8.761546894357763e-05
# Updated exact solution for case 15 with lambda 1.0: -0.05968738885826259
# Difference in expectation value: 0.033001316030166455
# Updated exact solution for case 30 with lambda 1.0: -0.38368303118405467
# Difference in expectation value: 0.05047869498275781
# Updated exact solution for case 83 with lambda 1.0: -0.2790042018104938
# Difference in expectation value: 0.0002789245273325802
# Updated exact solution for case 91 with lambda 1.0: -0.35119244251781095
# Difference in expectation value: 3.8575170584420615e-05
# Updated exact solution for case 57 with lambda 1.0: -0.1362355437118589
# Difference in expectation value: 0.0026529843484938975
# Updated exact solution for case 4 with lambda 1.0: -0.2538083969733328
# Difference in expectation value: 0.00025348110437684035
# Updated exact solution for case 95 with lambda 1.0: -0.35391476868053257
# Difference in expectation value: 2.781482323077622e-05
# Updated exact solution for case 50 with lambda 1.0: -0.20401694810591833
# Difference in expectation value: 0.003065517382875499
# Updated exact solution for case 70 with lambda 1.0: -0.4045115801527078
# Difference in expectation value: 0.10467121484350217
# Updated exact solution for case 62 with lambda 1.0: -0.2859359569412538
# Difference in expectation value: 0.022525515585258393
# Updated exact solution for case 31 with lambda 1.0: -0.4432320815551777
# Difference in expectation value: 0.0008426839157131272
# Updated exact solution for case 1 with lambda 1.0: -0.30874658777069186
# Difference in expectation value: 0.006840527069773228
# Updated exact solution for case 61 with lambda 1.0: -0.11707127266282864
# Difference in expectation value: 0.00021494405784439063
# Updated exact solution for case 36 with lambda 1.0: -0.32970880585874995
# Difference in expectation value: 0.05070891816352607
# Updated exact solution for case 0 with lambda 1.0: -0.2539760281971275
# Difference in expectation value: 0.0009203243423746565
# Updated exact solution for case 49 with lambda 1.0: -0.12968046118719276
# Difference in expectation value: 0.0023407013299079626
# Updated exact solution for case 32 with lambda 1.0: -0.25266805507239937
# Difference in expectation value: 0.0039043193635154294
# Updated exact solution for case 7 with lambda 1.0: -0.5906841157535581
# Difference in expectation value: 0.003656124019532747
# Updated exact solution for case 51 with lambda 1.0: -0.2614354758524762
# Difference in expectation value: 0.08366545574843609
# Updated exact solution for case 34 with lambda 1.0: -0.40873683127758487
# Difference in expectation value: 0.0012891559426712607
# Updated exact solution for case 75 with lambda 1.0: -0.5126952120185154
# Difference in expectation value: 0.3136919184420728
# Updated exact solution for case 10 with lambda 1.0: -0.22146911257460766
# Difference in expectation value: 0.00030751211027493786
# Updated exact solution for case 38 with lambda 1.0: -0.19210799794425396
# Difference in expectation value: 3.328036669950074e-05
# Updated exact solution for case 66 with lambda 1.0: -0.24878763024675976
# Difference in expectation value: 0.138045481959238
# Updated exact solution for case 74 with lambda 1.0: -0.2515648864571435
# Difference in expectation value: 0.014437868183492492
# Updated exact solution for case 53 with lambda 1.0: -0.11412303723219841
# Difference in expectation value: 0.00027976624687803264
# Processing lambda=0.9 folder...
# Updated exact solution for case 27 with lambda 0.9: -0.4290635533459759
# Difference in expectation value: 2.4358561425796843e-05
# Updated exact solution for case 79 with lambda 0.9: -0.2099602273071143
# Difference in expectation value: 0.0007735047850833954
# Updated exact solution for case 65 with lambda 0.9: -0.037525558028781686
# Difference in expectation value: 1.2950469443911983e-05
# Updated exact solution for case 67 with lambda 0.9: -0.14092657741485093
# Difference in expectation value: 0.0026927859220376438
# Updated exact solution for case 98 with lambda 0.9: -0.5270874839570461
# Difference in expectation value: 7.664039917398835e-05
# Updated exact solution for case 42 with lambda 0.9: -0.05501234057482793
# Difference in expectation value: 0.00023359576529520532
# Updated exact solution for case 80 with lambda 0.9: -0.2047533961756753
# Difference in expectation value: 7.265414626139721e-05
# Updated exact solution for case 24 with lambda 0.9: -0.12160181988121384
# Difference in expectation value: 3.515823946288743e-05
# Updated exact solution for case 87 with lambda 0.9: -0.596918332854828
# Difference in expectation value: 0.004924588943306163
# Updated exact solution for case 74 with lambda 0.9: -0.25574234209146196
# Difference in expectation value: 0.004177455634318483
# Updated exact solution for case 21 with lambda 0.9: -0.3213575653195616
# Difference in expectation value: 0.0004374129216319078
# Updated exact solution for case 22 with lambda 0.9: -0.5473800074037453
# Difference in expectation value: 8.900952479340418e-05
# Updated exact solution for case 55 with lambda 0.9: -0.2265995908740621
# Difference in expectation value: 0.0012262065527431643
# Updated exact solution for case 81 with lambda 0.9: -0.26565315276000706
# Difference in expectation value: 7.089995516518233e-06
# Updated exact solution for case 43 with lambda 0.9: -0.13361419659000023
# Difference in expectation value: 0.0010246225277754373
# Updated exact solution for case 10 with lambda 0.9: -0.22191146249400437
# Difference in expectation value: 0.0004423499193967062
# Updated exact solution for case 63 with lambda 0.9: -0.09737961355763816
# Difference in expectation value: 0.00011627621265228316
# Updated exact solution for case 68 with lambda 0.9: -0.3064629212607306
# Difference in expectation value: 0.002190786091873509
# Updated exact solution for case 53 with lambda 0.9: -0.11463241033479332
# Difference in expectation value: 0.0005093731025949122
# Updated exact solution for case 39 with lambda 0.9: -0.06724210039566314
# Difference in expectation value: 6.361283654401917e-06
# Updated exact solution for case 5 with lambda 0.9: -0.2538142138173796
# Difference in expectation value: 0.0008946344675346829
# Updated exact solution for case 94 with lambda 0.9: -0.23721048945945764
# Difference in expectation value: 1.5236552724534613e-05
# Updated exact solution for case 47 with lambda 0.9: -0.029401027819132824
# Difference in expectation value: 2.3891466998500477e-05
# Updated exact solution for case 4 with lambda 0.9: -0.2573668306292992
# Difference in expectation value: 0.00355843365596642
# Updated exact solution for case 40 with lambda 0.9: -0.042438381223299654
# Difference in expectation value: 0.00013806789818854998
# Updated exact solution for case 78 with lambda 0.9: -0.052653270280576175
# Difference in expectation value: 1.8331101379470693e-06
# Updated exact solution for case 92 with lambda 0.9: -0.13925191173679707
# Difference in expectation value: 1.3126550185371677e-05
# Updated exact solution for case 85 with lambda 0.9: -0.3226082877627081
# Difference in expectation value: 3.709686950709168e-05
# Updated exact solution for case 28 with lambda 0.9: -0.5267654352415784
# Difference in expectation value: 0.00158378383117308
# Updated exact solution for case 26 with lambda 0.9: -0.21841136785447085
# Difference in expectation value: 3.236082659324735e-05
# Updated exact solution for case 2 with lambda 0.9: -0.2578710753427355
# Difference in expectation value: 0.00016200808327976324
# Updated exact solution for case 49 with lambda 0.9: -0.13039245262627797
# Difference in expectation value: 0.0007119914390852078
# Updated exact solution for case 3 with lambda 0.9: -0.0682799951962218
# Difference in expectation value: 0.00019611696004928625
# Updated exact solution for case 86 with lambda 0.9: -0.12373838852529997
# Difference in expectation value: 4.9315380691153377e-05
# Updated exact solution for case 45 with lambda 0.9: -0.13991679093527648
# Difference in expectation value: 0.0022815783589841543
# Updated exact solution for case 99 with lambda 0.9: -0.303904050983865
# Difference in expectation value: 3.1288723220668224e-06
# Updated exact solution for case 90 with lambda 0.9: -0.20188747531002624
# Difference in expectation value: 2.1425074515080134e-06
# Updated exact solution for case 58 with lambda 0.9: -0.12836818940954614
# Difference in expectation value: 0.0003669475044422166
# Updated exact solution for case 89 with lambda 0.9: -0.14338582896110713
# Difference in expectation value: 2.209447902501438e-05
# Processing lambda=10.0 folder...
# Updated exact solution for case 61 with lambda 10.0: -0.11709289813396205
# Difference in expectation value: 2.1625471133407403e-05
# Updated exact solution for case 82 with lambda 10.0: -0.28790779869065325
# Difference in expectation value: 1.355193377788888e-05
# Updated exact solution for case 99 with lambda 10.0: -0.3039044068997398
# Difference in expectation value: 3.559158747723501e-07
# Updated exact solution for case 21 with lambda 10.0: -0.3214073733353012
# Difference in expectation value: 4.980801573961635e-05
# Updated exact solution for case 64 with lambda 10.0: -0.11974380842193508
# Difference in expectation value: 0.016618819826346165
# Updated exact solution for case 89 with lambda 10.0: -0.14338833255299235
# Difference in expectation value: 2.5035918852223116e-06
# Updated exact solution for case 9 with lambda 10.0: -0.343337565763801
# Difference in expectation value: 0.0006936324674804428
# Updated exact solution for case 18 with lambda 10.0: -0.1653176947379936
# Difference in expectation value: 0.005276362578561455
# Updated exact solution for case 34 with lambda 10.0: -0.4088661807609546
# Difference in expectation value: 0.00012934948336973395
# Updated exact solution for case 50 with lambda 10.0: -0.20432884952692207
# Difference in expectation value: 0.0003119014210037352
# Updated exact solution for case 60 with lambda 10.0: -0.11629319371237169
# Difference in expectation value: 1.4696420726406645e-05
# Updated exact solution for case 5 with lambda 10.0: -0.25393278509535727
# Difference in expectation value: 0.00011857127797765266
# Updated exact solution for case 67 with lambda 10.0: -0.14123953234530526
# Difference in expectation value: 0.00031295493045432887
# Updated exact solution for case 15 with lambda 10.0: -0.06811007454749367
# Difference in expectation value: 0.008422685689231081
# Updated exact solution for case 31 with lambda 10.0: -0.44331651843929454
# Difference in expectation value: 8.443688411685635e-05
# Updated exact solution for case 71 with lambda 10.0: -0.32199490073220977
# Difference in expectation value: 0.018244939805252658
# Updated exact solution for case 72 with lambda 10.0: -0.13297329448172496
# Difference in expectation value: 1.4372766067083376e-05
# Updated exact solution for case 7 with lambda 10.0: -0.5910539495102723
# Difference in expectation value: 0.0003698337567142884
# Updated exact solution for case 38 with lambda 10.0: -0.19211166354896173
# Difference in expectation value: 3.6656047077698872e-06
# Updated exact solution for case 87 with lambda 10.0: -0.5975788925293564
# Difference in expectation value: 0.0006605596745283826
# Updated exact solution for case 79 with lambda 10.0: -0.21004993572310193
# Difference in expectation value: 8.970841598762713e-05
# Updated exact solution for case 17 with lambda 10.0: -0.1083228247286823
# Difference in expectation value: 0.0008838119980720816
# Updated exact solution for case 49 with lambda 10.0: -0.13074898437134483
# Difference in expectation value: 0.0003565317450668626
# Updated exact solution for case 68 with lambda 10.0: -0.3078312644419118
# Difference in expectation value: 0.0013683431811811753
# Updated exact solution for case 36 with lambda 10.0: -0.3358140927019594
# Difference in expectation value: 0.006105286843209434
# Updated exact solution for case 8 with lambda 10.0: -0.36343700373303295
# Difference in expectation value: 0.0006778901752393929
# Updated exact solution for case 43 with lambda 10.0: -0.1344489732885195
# Difference in expectation value: 0.0008347766985192795
# Updated exact solution for case 4 with lambda 10.0: -0.25780812920111523
# Difference in expectation value: 0.00044129857181601784
# Updated exact solution for case 65 with lambda 10.0: -0.037527105136261465
# Difference in expectation value: 1.547107479779597e-06
# Updated exact solution for case 69 with lambda 10.0: -0.2100715733372931
# Difference in expectation value: 0.013502100286911484
# Updated exact solution for case 73 with lambda 10.0: -0.12407014105195106
# Difference in expectation value: 8.768301672304468e-06
# Updated exact solution for case 10 with lambda 10.0: -0.22199717612248424
# Difference in expectation value: 8.571362847986652e-05
# Updated exact solution for case 62 with lambda 10.0: -0.288401824257621
# Difference in expectation value: 0.0024658673163672207
# Updated exact solution for case 92 with lambda 10.0: -0.13925340504806363
# Difference in expectation value: 1.4933112665593828e-06
# Updated exact solution for case 29 with lambda 10.0: -0.25409076337545056
# Difference in expectation value: 0.007088000152017021
# Updated exact solution for case 25 with lambda 10.0: -0.6164300974657887
# Difference in expectation value: 2.330781175841068e-07
# Updated exact solution for case 93 with lambda 10.0: -0.22541993263861734
# Difference in expectation value: 2.648933259963293e-06
# Updated exact solution for case 63 with lambda 10.0: -0.09739285754337706
# Difference in expectation value: 1.3243985738903286e-05
# Updated exact solution for case 11 with lambda 10.0: -0.25223205476684146
# Difference in expectation value: 0.0028163454078957983
# Updated exact solution for case 19 with lambda 10.0: -0.07057236532036258
# Difference in expectation value: 0.00013865578607988316
# Updated exact solution for case 80 with lambda 10.0: -0.20476165099330756
# Difference in expectation value: 8.254817632252776e-06
# Updated exact solution for case 70 with lambda 10.0: -0.4191431206172847
# Difference in expectation value: 0.014631540464576931
# Updated exact solution for case 56 with lambda 10.0: -0.09837793409585913
# Difference in expectation value: 0.004940448427459887
# Updated exact solution for case 20 with lambda 10.0: -0.316107800673169
# Difference in expectation value: 2.7056437312711346e-05
# Updated exact solution for case 2 with lambda 10.0: -0.25789078999404863
# Difference in expectation value: 1.971465131311856e-05
# Updated exact solution for case 32 with lambda 10.0: -0.2527041065794467
# Difference in expectation value: 3.6051507047329956e-05
# Updated exact solution for case 3 with lambda 10.0: -0.06830237538874948
# Difference in expectation value: 2.2380192527676757e-05
# Updated exact solution for case 27 with lambda 10.0: -0.42906637057821656
# Difference in expectation value: 2.8172322406594397e-06
# Updated exact solution for case 47 with lambda 10.0: -0.0294037792956471
# Difference in expectation value: 2.751476514274709e-06
# Updated exact solution for case 85 with lambda 10.0: -0.3226124875075202
# Difference in expectation value: 4.199744812083406e-06
# Updated exact solution for case 30 with lambda 10.0: -0.38958374985936023
# Difference in expectation value: 0.005900718675305561
# ...
# Updated exact solution for case 21 with lambda 100.0: -0.321411790482548
# Difference in expectation value: 4.417147246749131e-06
# Updated exact solution for case 35 with lambda 100.0: -0.3929695961288303
# Difference in expectation value: 9.485917163931656e-06
# Updated exact solution for case 92 with lambda 100.0: -0.13925354462199557
# Difference in expectation value: 1.3957393193986256e-07
# Updated exact solution for case 15 with lambda 100.0: -0.06908496660883218
# Difference in expectation value: 0.0009748920613385087
# Updated exact solution for case 29 with lambda 100.0: -0.2548175422508434
# Difference in expectation value: 0.0007267788753928528
# Updated exact solution for case 20 with lambda 100.0: -0.31611050657627693
# Difference in expectation value: 2.705903107913521e-06
# Updated exact solution for case 94 with lambda 100.0: -0.23721237703250297
# Difference in expectation value: 1.542821791156168e-07
# Updated exact solution for case 26 with lambda 100.0: -0.21841539733301316
# Difference in expectation value: 3.2789230144936177e-07
# Updated exact solution for case 85 with lambda 100.0: -0.3226128836650133
# Difference in expectation value: 3.961574930877454e-07
# Updated exact solution for case 67 with lambda 100.0: -0.14126751737480037
# Difference in expectation value: 2.798502949510895e-05
# Updated exact solution for case 43 with lambda 100.0: -0.13456874257399903
# Difference in expectation value: 0.0001197692854795207
# Updated exact solution for case 23 with lambda 100.0: -0.3040697616032091
# Difference in expectation value: 1.1537393936889018e-06
# Updated exact solution for case 16 with lambda 100.0: -0.04186822061445057
# Difference in expectation value: 2.6715934641624584e-07
# Updated exact solution for case 25 with lambda 100.0: -0.6164301207691792
# Difference in expectation value: 2.3303390550566405e-08
# Updated exact solution for case 32 with lambda 100.0: -0.2527077122842647
# Difference in expectation value: 3.605704817999378e-06
# Updated exact solution for case 89 with lambda 100.0: -0.14338855630288322
# Difference in expectation value: 2.2374989086526575e-07
# Updated exact solution for case 47 with lambda 100.0: -0.02940402656385159
# Difference in expectation value: 2.472682044916963e-07
# Updated exact solution for case 81 with lambda 100.0: -0.2656540432592782
# Difference in expectation value: 8.398484829807984e-08
# Updated exact solution for case 14 with lambda 100.0: -0.11797170665468287
# Difference in expectation value: 5.482223172191547e-05
# Updated exact solution for case 80 with lambda 100.0: -0.20476238694691687
# Difference in expectation value: 7.359536093043406e-07
# Updated exact solution for case 87 with lambda 100.0: -0.5976792805422991
# Difference in expectation value: 0.00010038801294276478
# Updated exact solution for case 0 with lambda 100.0: -0.2540794803698784
# Difference in expectation value: 1.0095129458820296e-05
# Updated exact solution for case 66 with lambda 100.0: -0.27460156527573193
# Difference in expectation value: 0.00256549871900541
# Updated exact solution for case 28 with lambda 100.0: -0.526962341377402
# Difference in expectation value: 1.6096118916397728e-05
# Updated exact solution for case 68 with lambda 100.0: -0.3079536898140151
# Difference in expectation value: 0.0001224253721033297
# Updated exact solution for case 83 with lambda 100.0: -0.2790353536220089
# Difference in expectation value: 2.8322506126499114e-06
# Updated exact solution for case 71 with lambda 100.0: -0.3239429820121345
# Difference in expectation value: 0.0019480812799247404
# Updated exact solution for case 13 with lambda 100.0: -0.12310612531707019
# Difference in expectation value: 0.0010585483167429577
# Updated exact solution for case 77 with lambda 100.0: -0.18114027901468271
# Difference in expectation value: 1.4702580720532543e-05
# Updated exact solution for case 30 with lambda 100.0: -0.3901837946467082
# Difference in expectation value: 0.0006000447873479864
# Updated exact solution for case 78 with lambda 100.0: -0.0526534973685692
# Difference in expectation value: 1.856117839288407e-08
# Updated exact solution for case 24 with lambda 100.0: -0.12160883719550815
# Difference in expectation value: 1.1610254808530618e-06
# Updated exact solution for case 69 with lambda 100.0: -0.21152511212293373
# Difference in expectation value: 0.00145353878564064
# Updated exact solution for case 70 with lambda 100.0: -0.42066743846102345
# Difference in expectation value: 0.0015243178437387428
# Updated exact solution for case 18 with lambda 100.0: -0.16586452745876568
# Difference in expectation value: 0.000546832720772078
# Updated exact solution for case 33 with lambda 100.0: -0.25653691507924137
# Difference in expectation value: 8.7653482804817e-06
# Updated exact solution for case 65 with lambda 100.0: -0.03752724159533191
# Difference in expectation value: 1.364590704461266e-07
# Updated exact solution for case 95 with lambda 100.0: -0.3539178285582495
# Difference in expectation value: 2.7817345943370597e-07
# Updated exact solution for case 98 with lambda 100.0: -0.5270969242339218
# Difference in expectation value: 7.756103018730087e-07
# Updated exact solution for case 1 with lambda 100.0: -0.30952472290882427
# Difference in expectation value: 7.119417494777514e-05
# Updated exact solution for case 99 with lambda 100.0: -0.30390443858036903
# Difference in expectation value: 3.168062923109005e-08
# Updated exact solution for case 27 with lambda 100.0: -0.4290667566053683
# Difference in expectation value: 3.860271517441838e-07
# Updated exact solution for case 19 with lambda 100.0: -0.0705864227787414
# Difference in expectation value: 1.4057458378818888e-05
# Updated exact solution for case 5 with lambda 100.0: -0.2539433159279902
# Difference in expectation value: 1.0530832632915654e-05
# Updated exact solution for case 93 with lambda 100.0: -0.22542019753456033
# Difference in expectation value: 2.648959429862874e-07
# Updated exact solution for case 8 with lambda 100.0: -0.36350493110438137
# Difference in expectation value: 6.792737134841964e-05
# Updated exact solution for case 91 with lambda 100.0: -0.3511966862843146
# Difference in expectation value: 3.8580287903267063e-07
# Processing lambda=1000.0 folder...
# Updated exact solution for case 15 with lambda 1000.0: -0.06918424751623953
# Difference in expectation value: 9.928090740735085e-05
# Updated exact solution for case 68 with lambda 1000.0: -0.3079660231412318
# Difference in expectation value: 1.2333327216673684e-05
# Updated exact solution for case 76 with lambda 1000.0: -0.3906606887098113
# Difference in expectation value: 0.006393508365275746
# Updated exact solution for case 79 with lambda 1000.0: -0.2100591887226123
# Difference in expectation value: 8.412100700183611e-07
# Updated exact solution for case 3 with lambda 1000.0: -0.06830456746287802
# Difference in expectation value: 1.976062829062153e-07
# Updated exact solution for case 17 with lambda 1000.0: -0.10842126382959726
# Difference in expectation value: 8.95636391885779e-06
# Updated exact solution for case 20 with lambda 1000.0: -0.3161107771699418
# Difference in expectation value: 2.7059366486392733e-07
# Updated exact solution for case 32 with lambda 1000.0: -0.25270807286046953
# Difference in expectation value: 3.605762048386474e-07
# Updated exact solution for case 5 with lambda 1000.0: -0.2539444002627311
# Difference in expectation value: 1.0843347408862059e-06
# Updated exact solution for case 95 with lambda 1000.0: -0.353917856375584
# Difference in expectation value: 2.7817334491420098e-08
# Updated exact solution for case 30 with lambda 1000.0: -0.3902439006272294
# Difference in expectation value: 6.0105980521196756e-05
# Updated exact solution for case 80 with lambda 1000.0: -0.20476247344037393
# Difference in expectation value: 8.649345706324141e-08
# Updated exact solution for case 10 with lambda 1000.0: -0.22200584768371984
# Difference in expectation value: 8.442603892377942e-07
# Updated exact solution for case 83 with lambda 1000.0: -0.27903563685036664
# Difference in expectation value: 2.8322835776695143e-07
# Updated exact solution for case 1 with lambda 1000.0: -0.3095318440480706
# Difference in expectation value: 7.121139246335506e-06
# Updated exact solution for case 28 with lambda 1000.0: -0.5269639510412026
# Difference in expectation value: 1.6096638005835828e-06
# Updated exact solution for case 67 with lambda 1000.0: -0.14127035343664213
# Difference in expectation value: 2.836061841759996e-06
# Updated exact solution for case 18 with lambda 1000.0: -0.16591954104274106
# Difference in expectation value: 5.501358397538847e-05
# Updated exact solution for case 74 with lambda 1000.0: -0.25827556624290765
# Difference in expectation value: 2.0830134566440783e-05
# Updated exact solution for case 27 with lambda 1000.0: -0.42906679202238457
# Difference in expectation value: 3.5417016264194245e-08
# Updated exact solution for case 29 with lambda 1000.0: -0.25489172600577154
# Difference in expectation value: 7.418375492812546e-05
# Updated exact solution for case 91 with lambda 1000.0: -0.351196724864598
# Difference in expectation value: 3.858028341241493e-08
# Updated exact solution for case 60 with lambda 1000.0: -0.11629487279641243
# Difference in expectation value: 1.6081016218638666e-07
# Updated exact solution for case 14 with lambda 1000.0: -0.11797720029055418
# Difference in expectation value: 5.493635871309244e-06
# Updated exact solution for case 82 with lambda 1000.0: -0.28790928947852185
# Difference in expectation value: 1.3552704464236953e-07
# Updated exact solution for case 25 with lambda 1000.0: -0.6164301230996114
# Difference in expectation value: 2.330432180563946e-09
# Updated exact solution for case 24 with lambda 1000.0: -0.12160894661247838
# Difference in expectation value: 1.0941697023425512e-07
# Updated exact solution for case 90 with lambda 1000.0: -0.2018877428955102
# Difference in expectation value: 2.1694518681503183e-09
# Updated exact solution for case 89 with lambda 1000.0: -0.14338858877878444
# Difference in expectation value: 3.247590121824295e-08
# Updated exact solution for case 93 with lambda 1000.0: -0.22542022402415632
# Difference in expectation value: 2.6489595988943293e-08
# Updated exact solution for case 94 with lambda 1000.0: -0.2372123924607669
# Difference in expectation value: 1.5428263916428264e-08
# Updated exact solution for case 70 with lambda 1000.0: -0.4208204785790282
# Difference in expectation value: 0.0001530401180047658
# Updated exact solution for case 87 with lambda 1000.0: -0.5976893202432361
# Difference in expectation value: 1.0039700936936846e-05
# Updated exact solution for case 31 with lambda 1000.0: -0.4433258083876945
# Difference in expectation value: 8.445548742019859e-07
# Updated exact solution for case 51 with lambda 1000.0: -0.274280112315114
# Difference in expectation value: 0.00012109322882247753
# Updated exact solution for case 22 with lambda 1000.0: -0.547391125362877
# Difference in expectation value: 9.013812618530181e-08
# Updated exact solution for case 35 with lambda 1000.0: -0.392970544745387
# Difference in expectation value: 9.486165566952032e-07
# Updated exact solution for case 63 with lambda 1000.0: -0.09739414692288646
# Difference in expectation value: 1.1033917152181161e-07
# Updated exact solution for case 13 with lambda 1000.0: -0.1232130433441996
# Difference in expectation value: 0.00010691802712940734
# Updated exact solution for case 92 with lambda 1000.0: -0.13925355791428676
# Difference in expectation value: 1.3292291184408e-08
# Updated exact solution for case 16 with lambda 1000.0: -0.04186824733054959
# Difference in expectation value: 2.671609902055172e-08
# Updated exact solution for case 77 with lambda 1000.0: -0.1811417493980252
# Difference in expectation value: 1.4703833424722923e-06
# Updated exact solution for case 8 with lambda 1000.0: -0.3635118773995939
# Difference in expectation value: 6.946295212528764e-06
# Updated exact solution for case 47 with lambda 1000.0: -0.029404051057409127
# Difference in expectation value: 2.449355753636473e-08
# Updated exact solution for case 64 with lambda 1000.0: -0.121887819866569
# Difference in expectation value: 0.00019807739925944978
# Updated exact solution for case 2 with lambda 1000.0: -0.2578935776387004
# Difference in expectation value: 2.724422746847033e-07
# Updated exact solution for case 39 with lambda 1000.0: -0.06724289492410919
# Difference in expectation value: 6.4415581618737505e-09
# Updated exact solution for case 85 with lambda 1000.0: -0.3226129212303539
# Difference in expectation value: 3.756534061594152e-08
# Updated exact solution for case 21 with lambda 1000.0: -0.32141223407874336
# Difference in expectation value: 4.435961953874745e-07
# Updated exact solution for case 88 with lambda 1000.0: -0.4161123571559058
# Difference in expectation value: 3.166271663190834e-06
# Updated exact solution for case 34 with lambda 1000.0: -0.4088807136251408
# Difference in expectation value: 1.3346073482467524e-06
# Updated exact solution for case 9 with lambda 1000.0: -0.34341537902956426
# Difference in expectation value: 7.645440099235401e-06
# Updated exact solution for case 98 with lambda 1000.0: -0.5270970505973879
# Difference in expectation value: 1.2636346602423743e-07
# Updated exact solution for case 0 with lambda 1000.0: -0.2540805885316611
# Difference in expectation value: 1.1081617827257695e-06
# Updated exact solution for case 19 with lambda 1000.0: -0.07058782882765027
# Difference in expectation value: 1.4060489088724148e-06
# Updated exact solution for case 6 with lambda 1000.0: -0.3076677464879146
# Difference in expectation value: 2.2593881393084825e-05
# Updated exact solution for case 71 with lambda 1000.0: -0.32413908591878615
# Difference in expectation value: 0.00019610390665164568
# Updated exact solution for case 78 with lambda 1000.0: -0.05265349922468216
# Difference in expectation value: 1.8561129577765456e-09
# Updated exact solution for case 40 with lambda 1000.0: -0.0424557739260702
# Difference in expectation value: 1.6316726317924801e-06
# Updated exact solution for case 56 with lambda 1000.0: -0.09919976286011858
# Difference in expectation value: 5.102729881677204e-05
# Updated exact solution for case 38 with lambda 1000.0: -0.1921120667774834
# Difference in expectation value: 3.6657252122651585e-08
# Updated exact solution for case 72 with lambda 1000.0: -0.13297487567566096
# Difference in expectation value: 1.4374659823568336e-07
# Updated exact solution for case 62 with lambda 1000.0: -0.2886764613351864
# Difference in expectation value: 2.5715102293488723e-05
# Updated exact solution for case 7 with lambda 1000.0: -0.5910946953871844
# Difference in expectation value: 3.704389384129314e-06
# Updated exact solution for case 23 with lambda 1000.0: -0.30406987697738674
# Difference in expectation value: 1.1537417765605795e-07
# Updated exact solution for case 81 with lambda 1000.0: -0.26565405043817925
# Difference in expectation value: 7.178901029192275e-09
# Updated exact solution for case 86 with lambda 1000.0: -0.12374455021587519
# Difference in expectation value: 4.995722452383333e-08
# Updated exact solution for case 69 with lambda 1000.0: -0.21167162806060807
# Difference in expectation value: 0.0001465159376743408
# Updated exact solution for case 26 with lambda 1000.0: -0.2184154301220414
# Difference in expectation value: 3.2789028242552476e-08
# Updated exact solution for case 65 with lambda 1000.0: -0.037527256622314834
# Difference in expectation value: 1.502698292188409e-08
# Updated exact solution for case 33 with lambda 1000.0: -0.25653779164631313
# Difference in expectation value: 8.765670717614249e-07
# Updated exact solution for case 73 with lambda 1000.0: -0.1240711056353861
# Difference in expectation value: 8.768990460150672e-08
# Updated exact solution for case 66 with lambda 1000.0: -0.2748608320840214
# Difference in expectation value: 0.00025926680828947113
# Updated exact solution for case 36 with lambda 1000.0: -0.3365125672758567
# Difference in expectation value: 7.551617670570332e-05
# Updated exact solution for case 61 with lambda 1000.0: -0.11709527741905291
# Difference in expectation value: 2.1630282046047888e-07
# Loaded 100 cases.
